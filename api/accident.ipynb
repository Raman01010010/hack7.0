# %%
import pandas as pd
import numpy as np

# %%
traindata=pd.read_csv('AccidentsBig.csv')
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_9336\2754012341.py:1: DtypeWarning: Columns (8,10,28,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   traindata=pd.read_csv('AccidentsBig.csv')

# %%
traindata.head()
# Out:
#    Accident_Index  longitude   latitude  Police_Force  Accident_Severity  \
# 0             1.0  78.610393  14.724026           1.0                2.0
# 1             2.0  78.534042  14.762353           1.0                3.0
# 2             3.0  78.470877  14.745606           1.0                3.0
# 3             4.0  78.557994  14.667128           1.0                3.0
# 4             5.0  78.576431  14.703443           1.0                3.0
#
#    Number_of_Vehicles  Number_of_Casualties  Day_of_Week   Time  \
# 0                 1.0                   1.0          3.0  17:42
# 1                 1.0                   1.0          4.0  17:36
# 2                 2.0                   1.0          5.0  00:15
# 3                 1.0                   1.0          6.0  10:35
# 4                 1.0                   1.0          2.0  21:13
#
#    Local_Authority_(District)  ... Pedestrian_Crossing-Physical_Facilities  \
# ...

# %%
print(traindata.columns)
# Out:
# Index(['Accident_Index', 'longitude', 'latitude', 'Police_Force',
#        'Accident_Severity', 'Number_of_Vehicles', 'Number_of_Casualties',
#        'Day_of_Week', 'Time', 'Local_Authority_(District)',
#        'Local_Authority_(Highway)', '1st_Road_Class', '1st_Road_Number',
#        'Road_Type', 'Speed_limit', 'Junction_Detail', 'Junction_Control',
#        '2nd_Road_Class', '2nd_Road_Number',
#        'Pedestrian_Crossing-Human_Control',
#        'Pedestrian_Crossing-Physical_Facilities', 'Light_Conditions',
#        'Weather_Conditions', 'Road_Surface_Conditions',
#        'Special_Conditions_at_Site', 'Carriageway_Hazards',
#        'Urban_or_Rural_Area', 'Did_Police_Officer_Attend_Scene_of_Accident',
#        'LSOA_of_Accident_Location', 'Date'],
#       dtype='object')

# %%
import requests

def get_path_between_points(api_key, origin, destination):
    # Define the API endpoint URL
    endpoint = 'https://maps.googleapis.com/maps/api/directions/json'

    # Define the parameters for the API request
    params = {
        'origin': origin,
        'destination': destination,
        'key': api_key
    }

    # Send the API request
    response = requests.get(endpoint, params=params)
    
    # Check if the request was successful
    if response.status_code == 200:
        # Parse the JSON response
        data = response.json()
        
        # Extract the path from the response
        if 'routes' in data and len(data['routes']) > 0:
            steps = data['routes'][0]['legs'][0]['steps']
            path = [(step['start_location']['lat'], step['start_location']['lng']) for step in steps]
            path.append((steps[-1]['end_location']['lat'], steps[-1]['end_location']['lng']))
            return path
        else:
            print("No route found between the specified points.")
    else:
        print("Error:", response.status_code)

# Example usage
api_key = 'AIzaSyC8tfwaEKz18BqOeJ8pPplFCjIxJsuNbrU'
origin = 'gorakpaur,india'
destination = 'ayodhya,india'

path = get_path_between_points(api_key, origin, destination)
print("Path between", origin, "and", destination, ":", path)
# Out:
# Path between gorakpaur,india and ayodhya,india : [(26.7605569, 83.37318429999999), (26.7561309, 83.3730295), (26.7433592, 83.3688067), (26.7342679, 83.3590815), (26.7322451, 83.3377853), (26.7465517, 83.2515004), (26.7910128, 82.94925099999999), (26.7764735, 82.37922119999999), (26.7784744, 82.3714663), (26.7785511, 82.3714902), (26.8050447, 82.2201785), (26.8007436, 82.2218225), (26.8002664, 82.220985), (26.8080069, 82.209254), (26.8079077, 82.2089621), (26.7921558, 82.1998002)]

# %%
pip install folium --user
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Loading egg at c:\python311\lib\site-packages\vboxapi-1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330

# %%
import folium
from folium import PolyLine

def visualize_path(path):
    # Create a folium map centered at the first point in the path
    map1 = folium.Map(location=path[0], zoom_start=5)

    # Add a polyline to the map representing the path
    polyline = PolyLine(locations=path, color='blue')
    map1.add_child(polyline)

    # Display the map
    return map1


map1 = visualize_path(path)
map1.save('path.html')  # Save the map to an HTML file
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import requests

def get_paths_between_points(api_key, origin, destination):
    # Define the API endpoint URL
    endpoint = 'https://maps.googleapis.com/maps/api/directions/json'

    # Define the parameters for the API request
    params = {
        'origin': origin,
        'destination': destination,
        'key': api_key
    }

    # Send the API request
    response = requests.get(endpoint, params=params)
    
    # Check if the request was successful
    if response.status_code == 200:
        # Parse the JSON response
        data = response.json()
        
        # Extract paths from the response
        paths = []
        if 'routes' in data:
            for route in data['routes']:
                steps = route['legs'][0]['steps']
                path = [(step['start_location']['lat'], step['start_location']['lng']) for step in steps]
                path.append((steps[-1]['end_location']['lat'], steps[-1]['end_location']['lng']))
                paths.append(path)
            return paths
        else:
            print("No routes found between the specified points.")
            return None
    else:
        print("Error:", response.status_code)
        return None

# Example usage
api_key = 'AIzaSyC8tfwaEKz18BqOeJ8pPplFCjIxJsuNbrU'
origin = 'delhi,india'
destination = 'gwalior,india'

paths = get_paths_between_points(api_key, origin, destination)
if paths:
    for i, path in enumerate(paths, start=1):
        print("Path", i, "between", origin, "and", destination, ":", path)
else:
    print("No paths returned.")
# Out:
# Path 1 between delhi,india and gwalior,india : [(28.7040873, 77.1024072), (28.70391189999999, 77.1022401), (28.7037663, 77.1021109), (28.7035249, 77.1019008), (28.7022507, 77.1037709), (28.7004158, 77.1021729), (28.6994612, 77.1232179), (28.7106138, 77.1368497), (28.7308325, 77.1494764), (28.7378232, 77.1623602), (28.7336407, 77.1786506), (28.7294969, 77.19438219999999), (28.714156, 77.2268299), (28.6806435, 77.2293376), (28.6787932, 77.2295824), (28.6786462, 77.2296094), (28.6670075, 77.2339891), (28.6542587, 77.24967740000001), (28.6515956, 77.2659388), (28.6472612, 77.26875350000002), (28.631299, 77.27141499999999), (28.6160519, 77.28141839999999), (28.6066866, 77.2874415), (28.5961717, 77.2927457), (28.5860746, 77.2987934), (28.5851522, 77.30020189999999), (28.5586595, 77.3220978), (28.5556156, 77.32606059999999), (28.5552827, 77.32637439999999), (28.4498506, 77.4916124), (28.4485917, 77.4980357), (27.2237313, 78.1208399), (27.1098309, 78.0599085), (27.0956423, 78.0435717), (27.0
# ...

# %%
import requests

def get_paths_between_points(api_key, origin, destination, alternatives=True):
    # Define the API endpoint URL
    endpoint = 'https://maps.googleapis.com/maps/api/directions/json'

    # Define the parameters for the API request
    params = {
        'origin': origin,
        'destination': destination,
        'key': api_key,
        'alternatives': str(alternatives).lower()  # Convert boolean to string ('true' or 'false')
    }

    # Send the API request
    response = requests.get(endpoint, params=params)
    
    # Check if the request was successful
    if response.status_code == 200:
        # Parse the JSON response
        data = response.json()
        
        # Extract paths from the response
        paths = []
        if 'routes' in data:
            for route in data['routes']:
                steps = route['legs'][0]['steps']
                path = [(step['start_location']['lat'], step['start_location']['lng']) for step in steps]
                path.append((steps[-1]['end_location']['lat'], steps[-1]['end_location']['lng']))
                paths.append(path)
            return paths
        else:
            print("No routes found between the specified points.")
            return None
    else:
        print("Error:", response.status_code)
        return None

# Example usage
api_key = 'AIzaSyC8tfwaEKz18BqOeJ8pPplFCjIxJsuNbrU'
origin = 'gwalior,india'
destination = 'delhi,india'

paths = get_paths_between_points(api_key, origin, destination, alternatives=True)
if paths:
    for i, path in enumerate(paths, start=1):
        print("Path", i, "between", origin, "and", destination, ":", path)
else:
    print("No paths returned.")
# Out:
# Path 1 between gwalior,india and delhi,india : [(26.2123991, 78.1772074), (26.2124563, 78.17711), (26.214686, 78.17691119999999), (26.233752, 78.180933), (26.2385412, 78.17865309999999), (26.2488834, 78.1779581), (26.271373, 78.132857), (26.5174625, 77.96916689999999), (26.5174509, 77.9690636), (26.5217145, 77.9674576), (27.064968, 77.9828639), (27.1036227, 77.9958923), (27.0912902, 78.03444499999999), (27.1054692, 78.052438), (27.1051434, 78.0530967), (27.1125359, 78.0651984), (27.1131129, 78.06482009999999), (27.1146529, 78.0677979), (27.1164538, 78.0704813), (27.1328042, 78.08929409999999), (27.2236896, 78.12063119999999), (28.4483624, 77.4978273), (28.4490251, 77.4909958), (28.5542281, 77.32749539999999), (28.5622456, 77.31706319999999), (28.5708132, 77.31088199999999), (28.5859186, 77.2987179), (28.5962247, 77.29258990000001), (28.6107965, 77.2848418), (28.6251219, 77.27523599999999), (28.6309482, 77.2713149), (28.6476375, 77.268498), (28.6515125, 77.2657898), (28.6512013, 77.25
# ...

# %%
import folium
from folium import PolyLine

def visualize_paths(paths):
    # Create a folium map centered at the first point in the first path
    map1 = folium.Map(location=paths[0][0], zoom_start=5)

    # Add a polyline for each path
    for i, path in enumerate(paths, start=1):
        polyline = PolyLine(locations=path, color=f'#{i*20:06x}')  # Different color for each path
        map1.add_child(polyline)

    # Display the map
    return map1

# Example usage
# Assuming paths is a list of paths, each path represented as a list of coordinates (latitude, longitude)


map1 = visualize_paths(paths)
map1.save('paths.html')  # Save the map to an HTML file
map1

# %%
usedata = traindata[['Accident_Index','longitude','latitude','Accident_Severity']]

# %%
usedata
# Out:
#          Accident_Index  longitude   latitude  Accident_Severity
# 0                   1.0  78.610393  14.724026                2.0
# 1                   2.0  78.534042  14.762353                3.0
# 2                   3.0  78.470877  14.745606                3.0
# 3                   4.0  78.557994  14.667128                3.0
# 4                   5.0  78.576431  14.703443                3.0
# ...                 ...        ...        ...                ...
# 1048570             NaN        NaN        NaN                NaN
# 1048571             NaN        NaN        NaN                NaN
# 1048572             NaN        NaN        NaN                NaN
# 1048573             NaN        NaN        NaN                NaN
# 1048574             NaN        NaN        NaN                NaN
#
# [1048575 rows x 4 columns]

# %%
usedata = usedata.dropna()

# %%
import pandas as pd
from math import radians, sin, cos, sqrt, atan2

def haversine(lat1, lon1, lat2, lon2):
    # Convert latitude and longitude from degrees to radians
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])

    # Haversine formula
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    distance = 6371 * c  # Earth radius in kilometers
    return distance


# Filter accidents based on severity (optional)
# df = df[df['Accident_Severity'] == 1]  # Assuming 1 indicates the highest severity level

# Load the paths from source to destination (list of latitudes and longitudes)

# Calculate the distance threshold (e.g., 100 meters) within which an accident is considered to be on the path
distance_threshold = 0.1  # in kilometers

# Count the number of accidents on each path
accidents_counts = []
for path in paths:
    accidents_count = 0
    for _, accident in usedata.iterrows():
        for i in range(len(path) - 1):
            lat1, lon1 = path[i]
            lat2, lon2 = path[i + 1]
            distance = haversine(accident['latitude'], accident['longitude'], lat1, lon1)
            if distance <= distance_threshold:
                accidents_count += 1
                break  # Move to the next accident
    accidents_counts.append(accidents_count)

# Output the number of accidents on each path
for i, path in enumerate(paths, start=1):
    print(f"Number of accidents on path {i}: {accidents_counts[i - 1]}")
# Out:
# Number of accidents on path 1: 7

# %%
import pandas as pd
from math import radians, sin, cos, sqrt, atan2

def haversine(lat1, lon1, lat2, lon2):
    # Convert latitude and longitude from degrees to radians
    lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])

    # Haversine formula
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * atan2(sqrt(a), sqrt(1-a))
    distance = 6371 * c  # Earth radius in kilometers
    return distance



# Calculate the distance threshold (e.g., 100 meters) within which an accident is considered to be on the path
distance_threshold = 1  # in kilometers

# Pre-process the dataset to filter accidents within a certain latitude and longitude range
lat_min = min(lat for path in paths for lat, _ in path) - distance_threshold
lat_max = max(lat for path in paths for lat, _ in path) + distance_threshold
lon_min = min(lon for path in paths for _, lon in path) - distance_threshold
lon_max = max(lon for path in paths for _, lon in path) + distance_threshold
df_filtered = usedata[(usedata['latitude'].between(lat_min, lat_max)) & (usedata['longitude'].between(lon_min, lon_max))]

# Count the number of accidents on each path
accidents_counts = []
for path_index, path in enumerate(paths, start=1):
    path_accident_severity = 0
    for _, accident in df_filtered.iterrows():
        for i in range(len(path) - 1):
            lat1, lon1 = path[i]
            lat2, lon2 = path[i + 1]
            distance = haversine(accident['latitude'], accident['longitude'], lat1, lon1)
            if distance <= distance_threshold:
                path_accident_severity += accident['Accident_Severity']
                break  # Move to the next accident 
    accidents_counts.append(path_accident_severity)

# Output the total accident severity for each path
for i, path in enumerate(paths, start=1):
    print(f"Total accident severity on path {i}: {accidents_counts[i - 1]}")
# Out:
# Total accident severity on path 1: 2190.0
# Total accident severity on path 2: 1362.0
# Total accident severity on path 3: 2190.0
